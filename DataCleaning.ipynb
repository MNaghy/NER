# %%
import pandas as pd
import io
import string

# %%
df_raw = pd.read_csv('All.csv', encoding='utf-8')
df_raw.head()
# Out:
#                                           Resume_str Category Unnamed: 2  \
# 0           HR ADMINISTRATOR/MARKETING ASSOCIATE\...       HR        NaN
# 1           HR SPECIALIST, US HR OPERATIONS      ...       HR        NaN
# 2           HR DIRECTOR       Summary      Over 2...       HR        NaN
# 3           HR SPECIALIST       Summary    Dedica...       HR        NaN
# 4           HR MANAGER         Skill Highlights  ...       HR        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 157 Unnamed: 158 Unnamed: 159 Unnamed: 160  \
# ...

# %%
df=df_raw[['Category', 'Resume_str']]
df.head()
# Out:
#   Category                                         Resume_str
# 0       HR           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1       HR           HR SPECIALIST, US HR OPERATIONS      ...
# 2       HR           HR DIRECTOR       Summary      Over 2...
# 3       HR           HR SPECIALIST       Summary    Dedica...
# 4       HR           HR MANAGER         Skill Highlights  ...

# %%
df[['Resume_str', 'Category']]=df[['Resume_str', 'Category']].astype('string')
# Out:
# C:\Users\MohamedEl-Naghy\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
d=df.Resume_str.str.encode('ascii', 'ignore').str.decode('ascii')
d
# Out:
# 0                HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1                HR SPECIALIST, US HR OPERATIONS      ...
# 2                HR DIRECTOR       Summary      Over 2...
# 3                HR SPECIALIST       Summary    Dedica...
# 4                HR MANAGER         Skill Highlights  ...
#                               ...
# 2665    Computer Skills: - Proficient in MS office (Wo...
# 2666    - Willingness to accept the challenges. - Posi...
# 2667    PERSONAL SKILLS - Quick learner, - Eagerness t...
# 2668    COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 2669    Skill Set OS Windows XP/7/8/8.1/10 Database MY...
# Name: Resume_str, Length: 2670, dtype: object

# %%
df.insert(2, 'Cleaned_Resume', d)
df.head()
# Out:
#   Category                                         Resume_str  \
# 0       HR           HR ADMINISTRATOR/MARKETING ASSOCIATE
# ...
# 1       HR           HR SPECIALIST, US HR OPERATIONS      ...
# 2       HR           HR DIRECTOR       Summary      Over 2...
# 3       HR           HR SPECIALIST       Summary    Dedica...
# 4       HR           HR MANAGER         Skill Highlights  ...
#
#                                       Cleaned_Resume
# 0           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1           HR SPECIALIST, US HR OPERATIONS      ...
# 2           HR DIRECTOR       Summary      Over 2...
# 3           HR SPECIALIST       Summary    Dedica...
# 4           HR MANAGER         Skill Highlights  ...

# %%
df.head(10)
# Out:
#   Category                                         Resume_str  \
# 0       HR           HR ADMINISTRATOR/MARKETING ASSOCIATE
# ...
# 1       HR           HR SPECIALIST, US HR OPERATIONS      ...
# 2       HR           HR DIRECTOR       Summary      Over 2...
# 3       HR           HR SPECIALIST       Summary    Dedica...
# 4       HR           HR MANAGER         Skill Highlights  ...
# 5       HR           HR GENERALIST       Summary     Dedic...
# 6       HR           HR MANAGER       Summary    HUMAN RES...
# 7       HR           HR MANAGER         Professional Summa...
# 8       HR           HR SPECIALIST       Summary    Posses...
# 9       HR           HR CLERK       Summary    Translates ...
#
#                                       Cleaned_Resume
# 0           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1           HR SPECIALIST, US HR OPERATIONS      ...
# 2           HR DIRECTOR       Summary      Over 2...
# 3           HR SPECIALIST       Summary    Dedica...
# ...

# %%
df.to_csv('All_Cleaned.csv')
